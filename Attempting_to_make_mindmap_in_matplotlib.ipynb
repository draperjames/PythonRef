# %%
import matplotlib as mpl
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = ax.plot(t, s, lw=2)

ax.annotate('local max', xy=(1, 1), xytext=(3, -1.5),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )

ax.set_ylim(-2,2)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(1, figsize=(3,3))
ax = plt.subplot(111)

x,y = (.8,.8)
ann = ax.annotate("test 1",
                  xy=(x,y), xycoords='data',
                  xytext=(0.5, 0.5), textcoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="round4", fc="w"),
                  arrowprops=dict(arrowstyle="-|>",
                                  connectionstyle="arc3,rad=-0.5",
                                  fc="w"),)
an2 = ax.annotate("Test 2",
                  xy=(1.1, .9),
                  size=20,
                  xycoords=ann,
                  xytext=(.6,.4),
                  textcoords="offset points",
                  va="center", ha="left",
                  bbox=dict(boxstyle="round4", fc="w"),
                  arrowprops=dict(arrowstyle="<|-"))

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(3,2))
ax=plt.subplot(111)
an1 = ax.annotate("Test 1",
                  xy=(0.0, 0.5),
                  xycoords="data",
                  va="center", ha="center",
                  bbox=dict(boxstyle="round", fc="c"))

an2 = ax.annotate("Test 2",
                  xy=(1, 0.5), 
                  xycoords=an1,
                  xytext=(30,0),
                  textcoords="offset points",
                  va="center", ha="left",
                  bbox=dict(boxstyle="round", fc="w"),
                  arrowprops=dict(arrowstyle="<-"))
print(an2)
an3 = ax.annotate("Test 3",
                  xy=(1, 0.5),
                  xycoords=an2,
                  xytext=(30,0),
                  textcoords="offset points",
                  va="center", ha="left",
                  bbox=dict(boxstyle="round", fc="w"),
                  arrowprops=dict(arrowstyle="<-"))
plt.show()
# Out:
# Annotation(1,0.5,'Test 2')
