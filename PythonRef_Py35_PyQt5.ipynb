# %%
import sys
sys.version
# Out:
# '3.5.2 |Continuum Analytics, Inc.| (default, Jul  5 2016, 11:41:13) [MSC v.1900 64 bit (AMD64)]'

# %%
# !deactivate

# %%
# !conda list pyqt
# Out:
# # packages in environment at C:\Anaconda3\envs\py35withPyQt5:
# #
# pyqt                      5.6.0                    py35_1

# %%
from PyQt5.QtCore import Qt
import PyQt5.QtGui as QtGui
# dir(Qt)
QtGui.QPushButton("MyButton")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-dc059b5b5e24> in <module>()
#       2 import PyQt5.QtGui as QtGui
#       3 # dir(Qt)
# ----> 4 QtGui.QPushButton("MyButton")
#
# AttributeError: module 'PyQt5.QtGui' has no attribute 'QPushButton'

# %%
# import qtpy.QtGui as QtGui
# import qtpy.QtWidgets as QtWidgets
# import qtpy.QtCore as QtCore
# from qtpy.QtCore import (Signal, Slot, Qt)
from Qt import QtGui
button = QtGui.QPushButton("MyButton")

# %%
from Qt import QtGui
button = QtGui.QPushButton("MyButton")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-52b0a8da83d1> in <module>()
# ----> 1 import Qt
#
# ImportError: No module named 'Qt'
